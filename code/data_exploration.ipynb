# %%
import pandas as pd

data = pd.read_csv("../assets/person_course_2014.csv")

# %%
data.head()
# Out:
#                     course_id       userid_DI  registered  viewed  explored  \
# 0  HarvardX/CB22x/2013_Spring  MHxPC130442623           1       0         0
# 1         HarvardX/CS50x/2012  MHxPC130442623           1       1         0
# 2  HarvardX/CB22x/2013_Spring  MHxPC130275857           1       0         0
# 3         HarvardX/CS50x/2012  MHxPC130275857           1       0         0
# 4  HarvardX/ER22x/2013_Spring  MHxPC130275857           1       0         0
#
#    certified final_cc_cname_DI LoE_DI  YoB gender grade start_time_DI  \
# 0          0     United States    NaN  NaN    NaN     0    2012-12-19
# 1          0     United States    NaN  NaN    NaN     0    2012-10-15
# 2          0     United States    NaN  NaN    NaN     0    2013-02-08
# 3          0     United States    NaN  NaN    NaN     0    2012-09-17
# 4          0     United States    NaN  NaN    NaN     0    2012-12-19
#
#   last_event_DI  nevents  ndays_act  nplay_video  nchapters  nforum_posts  \
# ...

# %%
data.describe()
# Out:
#        registered         viewed       explored      certified            YoB  \
# count    641138.0  641138.000000  641138.000000  641138.000000  544533.000000
# mean          1.0       0.624299       0.061899       0.027587    1985.253279
# std           0.0       0.484304       0.240973       0.163786       8.891814
# min           1.0       0.000000       0.000000       0.000000    1931.000000
# 25%           1.0       0.000000       0.000000       0.000000    1982.000000
# 50%           1.0       1.000000       0.000000       0.000000    1988.000000
# 75%           1.0       1.000000       0.000000       0.000000    1991.000000
# max           1.0       1.000000       1.000000       1.000000    2013.000000
#
#              nevents      ndays_act    nplay_video      nchapters  \
# count  441987.000000  478395.000000  183608.000000  382385.000000
# mean      431.008018       5.710254     114.844173       3.634423
# std      1516.116057      11.866471     426.996844       4.490987
# ...

# %%
data.grade.unique()
# Out:
# array(['0', '0.07', '0.05', nan, '0.0', '0.13', '0.35', '1', '0.95',
#        '0.28', '0.04', '0.19', '0.18', '0.87', '0.01', '0.02', '0.62',
#        '0.9', '0.03', '0.89', '0.38', '0.06', '0.93', ' ', '0.11', '0.86',
#        '0.37', '0.84', '0.14', '0.68', '0.08', '0.8', '0.98', '0.71',
#        '0.75', '0.09', '0.91', '0.53', '0.21', '0.48', '0.85', '0.79',
#        '0.17', '0.63', '0.55', '0.92', '0.12', '0.77', '0.15', '0.78',
#        '0.67', '0.1', '0.96', '0.32', '0.61', '0.76', '0.88', '0.45',
#        '0.73', '0.81', '0.82', '0.26', '0.69', '0.29', '0.16', '0.59',
#        '0.94', '0.51', '0.24', '0.72', '0.25', '0.83', '0.97', '0.31',
#        '0.99', '0.23', '0.7', '0.27', '0.66', '0.36', '0.74', '0.4', '0.2',
#        '0.44', '0.22', '0.42', '0.65', '0.34', '0.5', '0.58', '0.57',
#        '0.6', '0.43', '0.3', '0.54', '0.49', '0.64', '0.52', '0.33',
#        '0.39', '0.47', '0.56', '0.46', '0.41', '1.01'], dtype=object)

# %%
data.grade.convert_objects(convert_numeric=True)
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   if __name__ == '__main__':
# 0         0.00
# 1         0.00
# 2         0.00
# 3         0.00
# 4         0.00
# 5         0.00
# 6         0.00
# 7         0.00
# 8         0.00
# 9         0.00
# 10        0.00
# 11        0.00
# 12        0.07
# 13        0.00
# 14        0.00
# 15        0.00
# 16        0.00
# 17        0.00
# 18        0.00
# 19        0.00
# 20        0.00
# 21        0.00
# 22        0.00
# 23        0.00
# 24        0.00
# 25        0.00
# 26        0.00
# 27        0.00
# 28        0.00
# 29        0.05
#           ...
# 641108     NaN
# 641109     NaN
# 641110     NaN
# 641111     NaN
# 641112     NaN
# 641113    0.00
# 641114     NaN
# 641115     NaN
# 641116     NaN
# 641117     NaN
# 641118     NaN
# 641119     NaN
# 641120    0.00
# 641121     NaN
# ...

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import seaborn as sb

# %%
data.grade.convert_objects(convert_numeric=True).plot()
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   if __name__ == '__main__':

# %%
data.grade.convert_objects(convert_numeric=True).hist()
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   if __name__ == '__main__':

# %%
d3 = data
d3.grade = d3.grade.convert_objects(convert_numeric=True)
d3.describe()
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   from ipykernel import kernelapp as app
#        registered         viewed       explored      certified            YoB  \
# count    641138.0  641138.000000  641138.000000  641138.000000  544533.000000
# mean          1.0       0.624299       0.061899       0.027587    1985.253279
# std           0.0       0.484304       0.240973       0.163786       8.891814
# min           1.0       0.000000       0.000000       0.000000    1931.000000
# 25%           1.0       0.000000       0.000000       0.000000    1982.000000
# 50%           1.0       1.000000       0.000000       0.000000    1988.000000
# 75%           1.0       1.000000       0.000000       0.000000    1991.000000
# max           1.0       1.000000       1.000000       1.000000    2013.000000
#
# ...

# %%
d3 = d3[d3.grade > 0.1]
d3.grade.hist()

# %%
data.YoB.dropna().hist(bins=20)

# %%
data.gender.unique()
# Out:
# array([nan, 'm', 'f', 'o'], dtype=object)

# %%
data.gender.value_counts()
# Out:
# m    411520
# f    142795
# o        17
# Name: gender, dtype: int64

# %%
data.gender.value_counts().plot(kind='bar', subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x113c74ad0>], dtype=object)

# %%
d2 = data
d2.gender.fillna("na", inplace=True)
d2.gender.value_counts().plot(kind='bar', subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1172d1e90>], dtype=object)

# %%
data2 = data.dropna()

# %%
plt.figure()
# generate a scatterplot inside the figure
plt.plot(data.grade, data.YoB, '.')
# show the plot
plt.show()

# %%
plt.figure()
# generate a scatterplot inside the figure
plt.plot(data.YoB,data.grade, '.')
# show the plot
plt.show()

# %%
data.LoE_DI.unique()
# Out:
# array([nan, 'Secondary', "Bachelor's", "Master's", 'Doctorate',
#        'Less than Secondary'], dtype=object)

# %%
data.LoE_DI.value_counts().plot(kind='bar', subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11a8839d0>], dtype=object)

# %%
data.final_cc_cname_DI.value_counts().transpose().plot(kind='bar', subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11286c090>], dtype=object)

# %%
data.course_id.value_counts().plot(kind='bar')

# %%
import seaborn as sb
data[[]]
sb.pairplot(iris_data.dropna(), hue='class')
